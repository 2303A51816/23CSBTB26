# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51816/23CSBTB26/blob/main/2303A51816_B26_A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
train=pd.read_csv('/MathE dataset (4).csv', sep=";", encoding='cp1252')

train.head()
# Out:
#    Student ID Student Country  Question ID  Type of Answer Question Level  \
# 0         647         Ireland           77               0          Basic
# 1          41        Portugal           77               1          Basic
# 2         340        Portugal           77               1          Basic
# 3         641           Italy           77               0          Basic
# 4         669        Portugal           77               1          Basic
#
#         Topic    Subtopic                                           Keywords
# 0  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
# 1  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
# 2  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
# 3  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...
# 4  Statistics  Statistics  Stem and Leaf diagram,Relative frequency,Sampl...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9546 entries, 0 to 9545
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Student ID       9546 non-null   int64
#  1   Student Country  9546 non-null   object
#  2   Question ID      9546 non-null   int64
#  3   Type of Answer   9546 non-null   int64
#  4   Question Level   9546 non-null   object
#  5   Topic            9546 non-null   object
#  6   Subtopic         9546 non-null   object
#  7   Keywords         9546 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 596.8+ KB

# %%
train.nunique()
# Out:
# Student ID         372
# Student Country      8
# Question ID        833
# Type of Answer       2
# Question Level       2
# Topic               14
# Subtopic            24
# Keywords           365
# dtype: int64

# %%
train.describe()
# Out:
#         Student ID  Question ID  Type of Answer
# count  9546.000000  9546.000000     9546.000000
# mean    775.402263   478.912319        0.468259
# std     460.590559   249.244061        0.499018
# min      26.000000    77.000000        0.000000
# 25%     380.000000   323.000000        0.000000
# 50%     885.000000   428.000000        0.000000
# 75%    1219.000000   571.000000        1.000000
# max    1565.000000  1549.000000        1.000000

# %%
train['Student ID']='Student_ID_'+train['Student ID'].astype('str')
train['Question ID']='Question_ID_'+train['Question ID'].astype('str')
train['Type of Answer']=train['Type of Answer'].replace({1:'Correct',
                                                        0:'Incorrect'})
train.head()
# Out:
#        Student ID Student Country     Question ID Type of Answer  \
# 0  Student_ID_647         Ireland  Question_ID_77      Incorrect
# 1   Student_ID_41        Portugal  Question_ID_77        Correct
# 2  Student_ID_340        Portugal  Question_ID_77        Correct
# 3  Student_ID_641           Italy  Question_ID_77      Incorrect
# 4  Student_ID_669        Portugal  Question_ID_77        Correct
#
#   Question Level       Topic    Subtopic  \
# 0          Basic  Statistics  Statistics
# 1          Basic  Statistics  Statistics
# 2          Basic  Statistics  Statistics
# 3          Basic  Statistics  Statistics
# 4          Basic  Statistics  Statistics
#
#                                             Keywords
# 0  Stem and Leaf diagram,Relative frequency,Sampl...
# 1  Stem and Leaf diagram,Relative frequency,Sampl...
# 2  Stem and Leaf diagram,Relative frequency,Sampl...
# 3  Stem and Leaf diagram,Relative frequency,Sampl...
# 4  Stem and Leaf diagram,Relative frequency,Sampl...

# %%
train['Keywords'].value_counts()
# Out:
# Keywords
# Linear application,Linearity                                                                                                   443
# Simplify expressions                                                                                                           401
# Subspace,Linear combination,Span                                                                                               401
# Linear independence,Span,Linear dependence                                                                                     399
# Range,Kernel                                                                                                                   344
#                                                                                                                               ...
# Minimum,Maximum,Lagrange multipliers,Saddle point,Unconstrained optimization,Second derivative test                              1
# ...

# %%
train[['Topic','Subtopic']].describe()
# Out:
#                  Topic       Subtopic
# count             9546           9546
# unique              14             24
# top     Linear Algebra  Vector Spaces
# freq              5726           2749

# %%
# !pip install autoviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.2/161.2 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.9/586.9 kB 34.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 65.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 2.1.2
#     Uninstalling xgboost-2.1.2:
#       Successfully uninstalled xgboost-2.1.2
# ...
